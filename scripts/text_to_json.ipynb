# %%
import socket

HOST = "0.0.0.0"   # Listen on Bluetooth PAN
PORT = 5000

server = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
server.bind((HOST, PORT))
# server.listen(1)



while True:
    data, addr = server.recvfrom(1024)
    print(f"Received message: {data.decode()} from {addr}")

conn.close()
